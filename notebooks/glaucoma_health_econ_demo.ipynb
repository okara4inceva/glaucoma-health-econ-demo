# %% [markdown]
# # Glaucoma Health Economics Demo
#
# This notebook demonstrates a rapid health economic model for early glaucoma detection.
#
# **Important:** The dataset is simulated and does not contain real patient data.

# %%
import pandas as pd
from pathlib import Path

base = Path('..')
patients = pd.read_csv(base / 'data' / 'glaucoma_demo_patients.csv')
patients.head()

# %% [markdown]
# ## Simulated cohort summary

# %%
patients[['age', 'iop_mmhg', 'annual_direct_cost_aed', 'estimated_productivity_loss_aed']].describe().round(2)

# %%
patients['risk_group'].value_counts()

# %% [markdown]
# ## Base-case model results

# %%
results = pd.read_csv(base / 'outputs' / 'base_case_results.csv')
results.T
